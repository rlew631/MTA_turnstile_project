# %% [markdown]
# Data from: http://web.mta.info/developers/turnstile.html
#
# Header descriptions: http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt

# %%
import pandas as pd
import os

# %%
files = os.listdir()
files
# Out:
# ['EDA.ipynb',
#  '.DS_Store',
#  'turnstile_200704.txt',
#  'turnstile_200905.txt',
#  '.ipynb_checkpoints',
#  'turnstile_200801.txt']

# %%
df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_200919.txt')

# %%
df.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/12/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/12/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/12/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/12/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/12/2020  12:00:00
#
#          DESC  ENTRIES  \
# 0     REGULAR  7457064
# 1     REGULAR  7457067
# 2     REGULAR  7457078
# 3     REGULAR  7457119
# 4  RECOVR AUD    26786
#
#    EXITS
# 0                                            2535856
# 1                                            2535861
# 2                                            2535876
# 3                                            2535920
# 4                                               4009

# %%
df.groupby('STATION').sum()
# Out:
#                      ENTRIES  \
# STATION
# 1 AV             19409616052
# 103 ST            6727157521
# 103 ST-CORONA     2641087500
# 104 ST           71045256460
# 110 ST            1718958114
# ...                      ...
# WOODLAWN          1364494676
# WORLD TRADE CTR  35237979702
# WTC-CORTLANDT    30977812657
# YORK ST           1239539767
# ZEREGA AV          109600483
#
#                  EXITS
# STATION
# 1 AV                                                   19757630232
# 103 ST                                                  5854488794
# 103 ST-CORONA                                           2699684945
# 104 ST                                                 41577060094
# 110 ST                                                  1648022421
# ...                                                            ...
# WOODLAWN                                                 524844583
# WORLD TRADE CTR                                        40573795351
# WTC-CORTLANDT                                            206311880
# YORK ST                                                  389107446
# ZEREGA AV                                                 68950593
#
# [379 rows x 2 columns]
